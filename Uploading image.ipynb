# %%
import cv2
import matplotlib.pyplot as plt
file_path = r"C:\Users\user\OneDrive\Desktop\saraswatimaa.webp"
img = cv2.imread(file_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off')
plt.show()
